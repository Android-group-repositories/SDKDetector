# %%
tmp = ["amplitude(com.amplitude)",
r"Mixpanel (com.mixpanel.ndroid)",
r"umeng(com.umeng.umsdk)",
r"firebase(com.google.firebase)",
r"Adjust  (com.adjust.sdk)",
r"yandex (com.yandex.android)",
r"flurry(com.flurry.android)",
r"alipay(com.alipay.sdk)",
r"onesignal (com.mixpanel.android)",
r"Braze(com.braze)",
r"Paypal(com.paypal)",
r"Stripe(com.stripe)",
r"alipay(com.alipay.sdk)",
r"twitter(com.twitter.sdk)",
r"kakao(com.kakao)",
r"line(com.linecorp.linesdk)",
r"tiktok(com.bytedance.sdk)",
r"Tapjoy(com.tapjoyl)",
r"ironsource(com.ironsource)",
r"unity3dads(com.unity3d.ads)",
r"applovin (com.applovin.sdk)",
r"inMobi()",
r"vungle or liftoff(com.vungle.warren)",
r"appsflyer(com.appsflyer)",
r"MoPub()",
r"start.io(com.startapp.startAppSDK)",
r"pollfish (com.pollfish.)",
r"Chartboost (com.chartboost)",
r"Sentry()",
r"crashlytics(com.google.firebase.crashlytics)",
r"dropbox(com.dropbox.android)",
r"Naver",
r"Zendest(zendesk.support)",
r"ZOOM(uz.zoom.sdk)",
r"Nuance ()",
r"unity3d(com.unity3d.services.analytics./com.unity3d.ads.)",
r"RevenuCat(com.revenuecat.purchases\com.revenuecat)",
r"Urban AirShip(com.urbanairship)",
r"wechat-sdk-android(com.tencent.mm.opensdk\com.tencent.mm.sdk)",
r"snap creative kit(com.snap.creativekit)",
r"AdMob/AdSense?",
]



tmp.sort()
print(tmp)
tmp2= [         "wechat-sdk-android", 
        "unity3dads", 
        "tiktok", 
        "snap creative kit", 
        "pollfish", 
        "line", 
        "crashlytics", 
        "alipay", 
        "Zendest", 
        "ZOOM", 
        "Urban AirShip", 
        "Stripe", 
        "RevenuCat", 
        "Paypal", 
        "Chartboost", 
        "Braze", 
        "Adjust", 
        "umeng", 
        "sharesdk", 
        "yandex", 
        "jiubang", 
        "ad4screen", 
        "growingIO", 
        "Sensors", 
        "baidu", 
        "talkingdata", 
        "zhuge", 
        "amplitude", 
        "kissmetrics", 
        "mixpanel", 
        "Heap", 
        "GA", 
        "Firebase", 
        "twitter ", 
        "bytedance", 
        "ironsource ", 
        "onesignal", 
        "vungle", 
        "squareup", 
        "kakao", 
        "applovin", 
        "amazon", 
        "startapp", 
        "appsflyer", 
        "tapjoy ", 
        "dropbox", 
        "unity3d"]
tmp2.sort()
print(tmp2)
# Out:
# ['AdMob/AdSense?', 'Adjust  (com.adjust.sdk)', 'Braze(com.braze)', 'Chartboost (com.chartboost)', 'Mixpanel (com.mixpanel.ndroid)', 'MoPub()', 'Naver', 'Nuance ()', 'Paypal(com.paypal)', 'RevenuCat(com.revenuecat.purchases\\com.revenuecat)', 'Sentry(？)', 'Stripe(com.stripe)', 'Tapjoy(com.tapjoyl)', 'Urban AirShip(com.urbanairship)', 'ZOOM(uz.zoom.sdk)', 'Zendest(zendesk.support)', 'alipay(com.alipay.sdk)', 'alipay(com.alipay.sdk)', 'amplitude(com.amplitude)', 'applovin (com.applovin.sdk)', 'appsflyer(com.appsflyer)', 'crashlytics(com.google.firebase.crashlytics)', 'dropbox(com.dropbox.android)', 'firebase(com.google.firebase)', 'flurry(com.flurry.android)', 'inMobi()', 'ironsource(com.ironsource)', 'kakao(com.kakao)', 'line(com.linecorp.linesdk)', 'onesignal (com.mixpanel.android)', 'pollfish (com.pollfish.)', 'snap creative kit(com.snap.creativekit)', 'start.io(com.startapp.startAppSDK)', 'tiktok(com.bytedance.sdk)', 'twitter(com.twitter.sdk)', 'umeng(com.umeng.umsdk)', 'unity3d(com
# ...

# %%
tmp = ['AdMob/AdSense?', 
'Adjust  (com.adjust.sdk)', 
'Braze(com.braze)', 
'Chartboost (com.chartboost)', 
'Mixpanel (com.mixpanel.ndroid)', 
'MoPub()', 
'Naver', 
'Nuance ()', 
'Paypal(com.paypal)', 
'RevenuCat(com.revenuecat.purchases\\com.revenuecat)', 
'Sentry(？)', 
'Stripe(com.stripe)', 
'Tapjoy(com.tapjoyl)', 
'Urban AirShip(com.urbanairship)', 
'ZOOM(uz.zoom.sdk)', 
'Zendest(zendesk.support)', 
'alipay(com.alipay.sdk)', 
'alipay(com.alipay.sdk)', 
'amplitude(com.amplitude)', 
'applovin (com.applovin.sdk)', 
'appsflyer(com.appsflyer)', 
'crashlytics(com.google.firebase.crashlytics)', 
'dropbox(com.dropbox.android)', 
'firebase(com.google.firebase)', 
'flurry(com.flurry.android)', 
'inMobi()', 
'ironsource(com.ironsource)', 
'kakao(com.kakao)', 
'line(com.linecorp.linesdk)', 
'onesignal (com.mixpanel.android)', 
'pollfish (com.pollfish.)', 
'snap creative kit(com.snap.creativekit)', 
'start.io(com.startapp.startAppSDK)', 
'tiktok(com.bytedance.sdk)', 
'twitter(com.twitter.sdk)', 
'umeng(com.umeng.umsdk)', 
'unity3d(com.unity3d.services.analytics./com.unity3d.ads.)', 
'unity3dads(com.unity3d.ads)', 
'vungle or liftoff(com.vungle.warren)', 
'wechat-sdk-android(com.tencent.mm.opensdk\\com.tencent.mm.sdk)', 
'yandex (com.yandex.android)']

# %%
["Firebase", 
"GA", 
"Heap", 
"Sensors", 
"ad4screen", 
"amazon", 
"amplitude", 
"applovin", 
"appsflyer", 
"baidu", 
"bytedance", 
"dropbox", 
"growingIO", 
"ironsource ", 
"jiubang", 
"kakao", 
"kissmetrics", 
"mixpanel", 
"onesignal", 
"sharesdk", 
"squareup", 
"startapp", 
"talkingdata", 
"tapjoy ", 
"twitter ", 
"umeng", 
"unity3d", 
"vungle", 
"yandex", 
"zhuge"]
